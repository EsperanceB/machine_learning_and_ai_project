# %% [markdown]
# ## Forecasting COVID-19 Daily New Cases with Prophet
#
# In this section, we use Facebook Prophet, a time series forecasting library, to predict daily new COVID-19 cases globally.
#
# **Approach:**
# - We start with a pre-processed time series of daily new cases.
# - Prophet automatically detects trends, seasonality, and holidays/outliers in the data.
# - We fit the Prophet model to the historical data and generate a forecast for the next 30 days.
# - The forecast plot shows both the predicted trend and the uncertainty interval.
# - We also plot model components to understand seasonality and overall trends.

# %%
pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.7-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.2.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from prophet) (3.8.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from prophet) (2.1.1)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.76-py3-none-any.whl.metadata (44 kB)
#      ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#      ---------------------------------------- 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Collecting tqdm>=4.36.1 (from prophet)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib_resources in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from prophet) (6.1.0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from importlib_resources->prophet) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hopeb\anaconda3.12\envs\env_ml_intelex\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.7-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.4/13.3 MB 8.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/13.3 MB 9.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.3/13.3 MB 8.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/13.3 MB 9.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/13.3 MB 9.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/13.3 MB 9.5 MB/s eta 0:00:02
#    -------- ------------------------------- 3.0/13.3 MB 9.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/13.3 MB 9.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.8/13.3 MB 9.4 MB/s eta 0:00:02
#    ------------ --------------------------- 4.3/13.3 MB 9.4 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/13.3 MB 9.4 MB/s eta 0:00:01
#    --------------- ------------------------ 5.1/13.3 MB 9.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.4/13.3 MB 9.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.9/13.3 MB 9.2 MB/s eta 0:00:01
#    ------------------- -------------------- 6.4/13.3 MB 9.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.8/13.3 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 7.2/13.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.6/13.3 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.9/13.3 MB 9.2 MB/s eta 0:00:01
#    ------------------------ --------------- 8.3/13.3 MB 9.1 MB/s eta 0:00:01
#    ------------------------- -------------- 8.6/13.3 MB 9.1 MB/s eta 0:00:01
#    --------------------------- ------------ 9.0/13.3 MB 9.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.3 MB 8.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.3 MB 8.9 MB/s eta 0:00:01
#    ------------------------------ --------- 10.1/13.3 MB 8.8 MB/s eta 0:00:01
#    ------------------------------- -------- 10.5/13.3 MB 8.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.9/13.3 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 11.3/13.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.3 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.3 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 12.5/13.3 MB 8.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.9/13.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 8.6 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
#    ---------------------------------------- 0.0/94.5 kB ? eta -:--:--
#    ---------------------------------------- 94.5/94.5 kB 5.3 MB/s eta 0:00:00
# Downloading holidays-0.76-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------- -------------------------- 0.4/1.1 MB 7.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 8.0 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.6 MB/s eta 0:00:00
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Installing collected packages: tqdm, stanio, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.5 holidays-0.76 prophet-1.1.7 stanio-0.5.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Prepare your data for Prophet: must have columns ['ds', 'y']
df = pd.read_csv('global_covid_new_cases.csv', parse_dates=['date'])
prophet_df = df[['date', 'smoothed_new_cases']].rename(columns={'date': 'ds', 'smoothed_new_cases': 'y'})

# Initialize and fit the Prophet model on the time series data
model = Prophet()
model.fit(prophet_df)
# Out:
# 01:40:52 - cmdstanpy - INFO - Chain [1] start processing
# 01:40:52 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a dataframe for future dates (here, we forecast 30 days into the future)
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)    # Generate the forecast for both historical and future dates

# %%
# Generate the forecast for both historical and future dates

# Plot the forecast. The plot shows:
# - Black dots: actual historical data points
# - Blue line: model forecast
# - Light blue area: forecast uncertainty interval

model.plot(forecast)
plt.title('Prophet Forecast: COVID-19 Daily New Cases')
plt.xlabel('Date')
plt.ylabel('Daily Cases')
plt.show()

# %% [markdown]
# ## Tip:
#
# If you want to fully customize the legend (for example, if you want to match specific lines/patches to labels), you can access the lines in the plot:

# %%
fig = model.plot(forecast)
plt.title('Prophet Forecast: COVID-19 Daily New Cases')
plt.xlabel('Date')
plt.ylabel('Daily Cases')
# Get handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels)
plt.show()

# %% [markdown]
# ## Forecast Components
#
# Prophet allows us to visualize the different components affecting the forecast:
# - **Trend:** The overall direction of the data over time.
# - **Weekly/Yearly Seasonality:** Recurring patterns detected by the model.
# - **Holidays/Events (if provided):** Spikes or drops around known dates.
#
# This helps us interpret what drives changes in daily COVID-19 cases.

# %% [markdown]
# ## Conclusion
#
# - Prophet enables robust forecasting of time series data with minimal feature engineering.
# - The model’s forecasts and uncertainty intervals give us insights into potential future trends.
# - Component plots help understand seasonal effects or anomalies in the data.
# - This approach can be easily adapted to other forecasting tasks in healthcare and beyond.
